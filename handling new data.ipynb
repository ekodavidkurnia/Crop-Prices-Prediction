# %%
import pandas as pd
old_data = pd.read_csv('semua.csv')

old_data.tail()
# Out:
#          Tanggal    Beras  Beras Kualitas Bawah I (kg)  \
# 1393  2021-05-24  11750.0                      10700.0
# 1394  2021-05-25  11750.0                      10700.0
# 1395  2021-05-26  11750.0                      10700.0
# 1396  2021-05-27  11750.0                      10700.0
# 1397  2021-05-28  11750.0                      10700.0
#
#       Beras Kualitas Bawah II (kg)  Beras Kualitas Medium I (kg)  \
# 1393                       10400.0                       11800.0
# 1394                       10400.0                       11800.0
# 1395                       10400.0                       11800.0
# 1396                       10400.0                       11800.0
# 1397                       10350.0                       11800.0
#
#       Beras Kualitas Medium II (kg)  Beras Kualitas Super I (kg)  \
# 1393                        11550.0                      13050.0
# 1394                        11550.0                      13050.0
# ...

# %%
old_data.columns
# Out:
# Index(['Tanggal', 'Beras', 'Beras Kualitas Bawah I (kg)',
#        'Beras Kualitas Bawah II (kg)', 'Beras Kualitas Medium I (kg)',
#        'Beras Kualitas Medium II (kg)', 'Beras Kualitas Super I (kg)',
#        'Beras Kualitas Super II (kg)', 'Bawang Merah',
#        'Bawang Merah Ukuran Sedang (kg)', 'Bawang Putih',
#        'Bawang Putih Ukuran Sedang (kg)', 'Cabai Merah',
#        'Cabai Merah Besar (kg)', 'Cabai Merah Keriting  (kg)', 'Cabai Rawit',
#        'Cabai Rawit Hijau (kg)', 'Cabai Rawit Merah (kg)'],
#       dtype='object')

# %%
import os
os.rename('data baru juli','data baru juli.csv')

# %%
import pandas as pd
new_data = pd.read_csv('data baru juli.csv')

new_data.head()
# Out:
#       Tanggal    Beras  Beras Kualitas Bawah I (kg)  \
# 0  28/05/2021  11750.0                      10700.0
# 1  31/05/2021  11700.0                      10700.0
# 2  02/06/2021  11750.0                      10700.0
# 3  03/06/2021  11750.0                      10700.0
# 4  04/06/2021  11750.0                      10700.0
#
#    Beras Kualitas Bawah II (kg)  Beras Kualitas Medium I (kg)  \
# 0                       10400.0                       11800.0
# 1                       10350.0                       11750.0
# 2                       10350.0                       11750.0
# 3                       10350.0                       11750.0
# 4                       10350.0                       11750.0
#
#    Beras Kualitas Medium II (kg)  Beras Kualitas Super I (kg)  \
# 0                        11550.0                      13050.0
# 1                        11550.0                      13000.0
# 2                        11550.0                      13050.0
# ...

# %%
new_data['Tanggal'] = pd.to_datetime(new_data['Tanggal'], infer_datetime_format=True)

# %%
new_data = new_data.set_index('Tanggal')

# %%
new_data
# Out:
#               Beras  Beras Kualitas Bawah I (kg)  \
# Tanggal
# 2021-05-28  11750.0                      10700.0
# 2021-05-31  11700.0                      10700.0
# 2021-06-02  11750.0                      10700.0
# 2021-06-03  11750.0                      10700.0
# 2021-06-04  11750.0                      10700.0
# 2021-06-07  11750.0                      10700.0
# 2021-06-08  11750.0                      10700.0
# 2021-06-09  11750.0                      10700.0
# 2021-06-10  11700.0                      10700.0
# 2021-06-11  11700.0                      10700.0
# 2021-06-14  11750.0                      10700.0
# 2021-06-15  11750.0                      10700.0
# 2021-06-16  11750.0                      10700.0
# 2021-06-17  11750.0                      10700.0
# 2021-06-18  11750.0                      10700.0
# 2021-06-21  11750.0                      10700.0
# 2021-06-22  11750.0                      10700.0
# 2021-06-23  11750.0                      10700.0
# ...

# %%
dt = pd.date_range('2021-05-28', '2021-07-03')
idx = pd.DatetimeIndex(dt)
new_data = new_data.reindex(idx)

# %%
new_data.isnull().sum()
# Out:
# Beras                              12
# Beras Kualitas Bawah I (kg)        12
# Beras Kualitas Bawah II (kg)       12
# Beras Kualitas Medium I (kg)       12
# Beras Kualitas Medium II (kg)      12
# Beras Kualitas Super I (kg)        12
# Beras Kualitas Super II (kg)       12
# Bawang Merah                       12
# Bawang Merah Ukuran Sedang (kg)    12
# Bawang Putih                       12
# Bawang Putih Ukuran Sedang (kg)    12
# Cabai Merah                        12
# Cabai Merah Besar (kg)             12
# Cabai Merah Keriting  (kg)         12
# Cabai Rawit                        12
# Cabai Rawit Hijau (kg)             12
# Cabai Rawit Merah (kg)             12
# dtype: int64

# %%
new_data.columns == old_data.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True])

# %% [markdown]
# method to handle missing value in time series data
#
# - drop
# - ffill
# - bfill
# - rolling window fill
# - offset fill
# - interpolate

# %% [markdown]
# ### Interpolate missing value

# %%
df = new_data.interpolate()

# %%
new_data
# Out:
#               Beras  Beras Kualitas Bawah I (kg)  \
# 2021-05-28  11750.0                      10700.0
# 2021-05-29      NaN                          NaN
# 2021-05-30      NaN                          NaN
# 2021-05-31  11700.0                      10700.0
# 2021-06-01      NaN                          NaN
# 2021-06-02  11750.0                      10700.0
# 2021-06-03  11750.0                      10700.0
# 2021-06-04  11750.0                      10700.0
# 2021-06-05      NaN                          NaN
# 2021-06-06      NaN                          NaN
# 2021-06-07  11750.0                      10700.0
# 2021-06-08  11750.0                      10700.0
# 2021-06-09  11750.0                      10700.0
# 2021-06-10  11700.0                      10700.0
# 2021-06-11  11700.0                      10700.0
# 2021-06-12      NaN                          NaN
# 2021-06-13      NaN                          NaN
# 2021-06-14  11750.0                      10700.0
# ...

# %%
df
# Out:
#                    Beras  Beras Kualitas Bawah I (kg)  \
# 2021-05-28  11750.000000                      10700.0
# 2021-05-29  11733.333333                      10700.0
# 2021-05-30  11716.666667                      10700.0
# 2021-05-31  11700.000000                      10700.0
# 2021-06-01  11725.000000                      10700.0
# 2021-06-02  11750.000000                      10700.0
# 2021-06-03  11750.000000                      10700.0
# 2021-06-04  11750.000000                      10700.0
# 2021-06-05  11750.000000                      10700.0
# 2021-06-06  11750.000000                      10700.0
# 2021-06-07  11750.000000                      10700.0
# 2021-06-08  11750.000000                      10700.0
# 2021-06-09  11750.000000                      10700.0
# 2021-06-10  11700.000000                      10700.0
# 2021-06-11  11700.000000                      10700.0
# 2021-06-12  11716.666667                      10700.0
# ...

# %%
df.to_csv('new_data_diyas.csv')

# %%
df.columns == data.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
data = pd.read_csv('cleaned_data_pangan.csv')

data.tail()
# Out:
#          Tanggal    Beras  Beras Kualitas Bawah I (kg)  \
# 1365  2021-04-26  11750.0                      10750.0
# 1366  2021-04-27  11750.0                      10750.0
# 1367  2021-04-28  11750.0                      10750.0
# 1368  2021-04-29  11750.0                      10750.0
# 1369  2021-04-30  11750.0                      10750.0
#
#       Beras Kualitas Bawah II (kg)  Beras Kualitas Medium I (kg)  \
# 1365                       10450.0                       11800.0
# 1366                       10450.0                       11800.0
# 1367                       10450.0                       11800.0
# 1368                       10400.0                       11750.0
# 1369                       10400.0                       11800.0
#
#       Beras Kualitas Medium II (kg)  Beras Kualitas Super I (kg)  \
# 1365                        11600.0                      13050.0
# 1366                        11600.0                      13050.0
# ...

# %%
data['Tanggal'] = pd.to_datetime(data['Tanggal'], infer_datetime_format=True)

# %%
data = data.set_index('Tanggal')

# %%
data.shape
# Out:
# (1370, 17)

# %%
data = data.iloc[:-1,:]

# %%
data.shape
# Out:
# (1369, 17)

# %%
data
# Out:
#               Beras  Beras Kualitas Bawah I (kg)  \
# Tanggal
# 2017-07-31  11200.0                      10150.0
# 2017-08-01  11200.0                      10150.0
# 2017-08-02  11200.0                      10150.0
# 2017-08-03  11200.0                      10150.0
# 2017-08-04  11300.0                      10150.0
# ...             ...                          ...
# 2021-04-25  11750.0                      10750.0
# 2021-04-26  11750.0                      10750.0
# 2021-04-27  11750.0                      10750.0
# 2021-04-28  11750.0                      10750.0
# 2021-04-29  11750.0                      10750.0
#
#             Beras Kualitas Bawah II (kg)  Beras Kualitas Medium I (kg)  \
# Tanggal
# 2017-07-31                        9650.0                       11250.0
# 2017-08-01                        9650.0                       11250.0
# 2017-08-02                        9650.0                       11250.0
# ...

# %%
semua = pd.concat([data, df])

# %%
semua.shape
# Out:
# (1398, 17)

# %%
semua['2021-04-29':'2021-05-4']
# Out:
#               Beras  Beras Kualitas Bawah I (kg)  \
# 2021-04-29  11750.0                      10750.0
# 2021-04-30  11750.0                      10750.0
# 2021-05-01  11750.0                      10750.0
# 2021-05-02  11750.0                      10750.0
# 2021-05-03  11750.0                      10750.0
# 2021-05-04  11750.0                      10750.0
#
#             Beras Kualitas Bawah II (kg)  Beras Kualitas Medium I (kg)  \
# 2021-04-29                       10400.0                       11750.0
# 2021-04-30                       10400.0                       11800.0
# 2021-05-01                       10400.0                       11800.0
# 2021-05-02                       10400.0                       11800.0
# 2021-05-03                       10400.0                       11800.0
# 2021-05-04                       10400.0                       11800.0
#
#             Beras Kualitas Medium II (kg)  Beras Kualitas Super I (kg)  \
# ...

# %%
semua.shape
# Out:
# (1398, 17)

# %%
semua.to_csv('semua.csv')
